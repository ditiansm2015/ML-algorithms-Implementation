# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/ditiansm2015/ML-algorithms-Implementation/blob/master/Linear_Regression.ipynb)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
plt.scatter(df.price,df.bedrooms)
plt.title("Price vs Bedrooms")
plt.xlabel('Price')
plt.ylabel('Bedrooms')
# Out:
# Text(0,0.5,'Bedrooms')

# %%
plt.scatter(df.price,df.floors)
plt.title("Price vs Floors")
plt.xlabel('Price')
plt.ylabel('Floors')
# Out:
# Text(0,0.5,'Floors')

# %%
plt.scatter(df.price,df.waterfront)
plt.title("Price vs Waterfront")
plt.xlabel('Price')
plt.ylabel('Waterfront')
# Out:
# Text(0,0.5,'Waterfront')

# %%
plt.scatter(df.price,df.condition)
plt.title("Price vs Condition")
plt.xlabel('Price')
plt.ylabel('condition')
# Out:
# Text(0,0.5,'condition')

# %%
plt.scatter(df.price,df.lat)
plt.title("Price vs Latitude")
plt.xlabel('Price')
plt.ylabel('Latitude')
# Out:
# Text(0,0.5,'Latitude')

# %%
plt.scatter(df.price,df.long)
plt.title("Price vs Longitude")
plt.xlabel('Price')
plt.ylabel('Longitude')
# Out:
# Text(0,0.5,'Longitude')

# %%
plt.scatter(df.price,df.sqft_living)
plt.title("Price vs Square Feet")
plt.xlabel("Price")
plt.ylabel("Square feet")
# Out:
# Text(0,0.5,'Square feet')

# %%
plt.scatter(df.price,df.yr_built)
plt.title("Price vs Year Built")
plt.xlabel("price")
plt.ylabel('Year Built')
# Out:
# Text(0,0.5,'Year Built')

# %%
plt.scatter(df.price,df.yr_renovated)
plt.title("Price vs Year Renovated")
plt.xlabel("price")
plt.ylabel('Year Renovated')
# Out:
# Text(0,0.5,'Year Renovated')

# %%
plt.scatter(df.price,df.zipcode)
plt.title("Price vs Zip Code")
plt.xlabel("price")
plt.ylabel('Zip Code')
# Out:
# Text(0,0.5,'Zip Code')

# %%
plt.scatter(df.price,df.grade)
plt.title("Price vs Grade")
plt.xlabel("price")
plt.ylabel('Grade')
# Out:
# Text(0,0.5,'Grade')

# %%
# importing LinearRegression library
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
# importing train_test_split to split the dataset into training set and test set
from sklearn.cross_validation import train_test_split

# %%
# declaring 'price' as output variable 
labels = df['price']

# declaring all the variables except 'price' and 'date' as Features  
xtrain = df.drop(['price','date'],axis=1)

# %%
# breaking dataset as test and train set
x_train , x_test , y_train , y_test = train_test_split(xtrain , labels , test_size = 0.30,random_state =1)

# %%
# fitting training set into model
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# feeding model with test set to know the accuracy of the model
reg.score(x_test,y_test)
# Out:
# 0.6902831048106299
